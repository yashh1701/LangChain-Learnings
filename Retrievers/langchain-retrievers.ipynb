# %%
import os

key = os.getenv("OPENAI_API_KEY")

# Set your OpenAI API key
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ## Wikipedia Retriever

# %%
from langchain_community.retrievers import WikipediaRetriever
# Out:
# C:\Users\yashs\AppData\Local\Temp\ipykernel_4808\2879121110.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.retrievers import WikipediaRetriever

# %%
# Initialize the retriever (optional: set language and top_k)
retriever = WikipediaRetriever(top_k_results=2, lang="en")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Initialize the retriever (optional: set language and top_k)
# ----> 2 retriever = WikipediaRetriever(top_k_results=2, lang="en")
#
# NameError: name 'WikipediaRetriever' is not defined

# %%
# Define your query
query = "the geopolitical history of india and pakistan from the perspective of a chinese"
docs = retriever.invoke(query) # Get relevant Wikipedia documents
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Define your query
#       2 query = "the geopolitical history of india and pakistan from the perspective of a chinese"
# ----> 3 docs = retriever.invoke(query) # Get relevant Wikipedia documents
#
# NameError: name 'retriever' is not defined

# %%
docs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 docs
#
# NameError: name 'docs' is not defined

# %%
# Print retrieved content
for i, doc in enumerate(docs):
    print(f"\n--- Result {i+1} ---")
    print(f"Content:\n{doc.page_content}...")  # truncate for display

# %% [markdown]
# ## Vector Store Retriever
#
# *   List item
# *   List item

# %%
from langchain_community.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings
from langchain_core.documents import Document
